# %%
# %cd "F:\milestone02"
# Out:
# f:\milestone02

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")

results = model.train(data= "uni.yaml", epochs=30)
# Out:
# New https://pypi.org/project/ultralytics/8.2.7 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.4  Python-3.11.0 torch-2.2.2+cpu CPU (AMD Ryzen 5 7600X 6-Core Processor)
# ...

# %%
# !yolo task=detect mode=val model=best.pt data='uni.yaml'
# Out:
# Ultralytics YOLOv8.2.3 🚀 Python-3.11.0 torch-2.2.2+cpu CPU (AMD Ryzen 5 7600X 6-Core Processor)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\ironhide\AppData\Local\Programs\Python\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\ironhide\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\cfg\__init__.py", line 582, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ironhide\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py", line 527, in val
#     validator(model=self.model)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('best.pt')

# Define path to the image file
source = r'F:\milestone02\test'

# Run inference on the source
results = model(source)
# Out:
# image 1/362 F:\milestone02\test\1003.png: 384x640 5 signboards, 92.3ms
# image 2/362 F:\milestone02\test\1008.png: 384x640 1 signboard, 34.1ms
# image 3/362 F:\milestone02\test\1009.png: 384x640 2 signboards, 32.1ms
# image 4/362 F:\milestone02\test\1012.png: 384x640 2 signboards, 33.1ms
# image 5/362 F:\milestone02\test\1018.png: 384x640 4 signboards, 32.1ms
# image 6/362 F:\milestone02\test\1027.png: 384x640 4 signboards, 33.1ms
# image 7/362 F:\milestone02\test\11.png: 384x640 1 signboard, 32.1ms
# image 8/362 F:\milestone02\test\12.png: 384x640 5 signboards, 32.1ms
# image 9/362 F:\milestone02\test\1441.png: 384x640 2 signboards, 39.1ms
# image 10/362 F:\milestone02\test\1460.png: 384x640 2 signboards, 35.9ms
# image 11/362 F:\milestone02\test\1463.png: 384x640 5 signboards, 32.1ms
# image 12/362 F:\milestone02\test\1484.png: 384x640 5 signboards, 32.1ms
# image 13/362 F:\milestone02\test\1485.png: 384x640 1 signboard, 32.1ms
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Replace 'your_file.csv' with the actual filename
data = pd.read_csv(r'F:\milestone02\runs\detect\train2\results.csv')
data
# Out:
#                    epoch        train/box_loss        train/cls_loss  \
# 0                      1                3.8694               3.54640
# 1                      2                2.6698               2.59560
# 2                      3                2.0621               2.10780
# 3                      4                1.8061               1.86310
# 4                      5                1.6437               1.67540
# 5                      6                1.5340               1.60360
# 6                      7                1.4891               1.52780
# 7                      8                1.4303               1.45960
# 8                      9                1.3881               1.39910
# 9                     10                1.3612               1.35020
# 10                    11                1.3398               1.32180
# 11                    12                1.3072               1.29980
# 12                    13                1.2796               1.25150
# ...

# %%
column_1 = data.iloc[:, 0]
column_2 = data.iloc[:, 6] 
column_3 = data.iloc[:, 0]  
column_4 = data.iloc[:, 6]

# %%
plt.plot(column_3, column_4)  
plt.xlabel(data.columns[0]) 
plt.ylabel(data.columns[6]) 
plt.title('mAP50')  
plt.show()  


plt.plot(column_1, column_2)  
plt.xlabel(data.columns[0]) 
plt.ylabel(data.columns[7])  
plt.title('mAP50-95')  
plt.show()
